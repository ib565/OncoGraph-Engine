# %% [markdown]
# # Baseline Evaluation: Model-Agnostic Evaluation System
#
# This notebook evaluates baseline performance for multiple models:
# - **Gemini 2.0 Flash** (2-step pipeline)
# - **Gemini 2.5 Flash Lite** (2-step pipeline)
# - **Qwen3-4B-Instruct-2507** (base model, untuned)
#
# Metrics tracked:
# - Syntactic validity (passes RuleBasedValidator)
# - Execution success (runs on Neo4j)
# - Output accuracy (exact result match with gold Cypher)
# - Latency (ms)
# - Token usage (input/output tokens)

# %%
# Setup & Configuration

import json
import os
import sys
from collections import defaultdict
from pathlib import Path
from typing import Any

import pandas as pd
from dotenv import load_dotenv

# Add project root to path
ROOT = Path(os.getcwd()).resolve()

# Walk up until we find a directory with both pyproject.toml AND src/
found_root = False
while True:
    has_pyproject = (ROOT / "pyproject.toml").exists()
    has_src = (ROOT / "src").exists() and (ROOT / "src").is_dir()

    if has_pyproject and has_src:
        found_root = True
        break

    parent = ROOT.parent
    if parent == ROOT:
        break
    ROOT = parent

if not found_root:
    raise FileNotFoundError(
        f"Could not find project root (directory with both pyproject.toml and src/). "
        f"Current directory: {os.getcwd()}. "
        f"Please set ROOT manually above."
    )

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print(f"Project root: {ROOT}")
print(f"Current working directory: {os.getcwd()}")
print(f"src module verified at: {ROOT / 'src'}")

from src.pipeline.executor import Neo4jExecutor
from src.pipeline.types import PipelineConfig
from src.pipeline.validator import RuleBasedValidator

load_dotenv()

# Configuration
# Models to evaluate (supports single model in list or multiple models)
MODELS_TO_RUN = [
    "gemini-2.5-flash",
    # "gemini-2.5-flash-lite",
    # "qwen3-4b-it-2507-base",
]
TEST_SUBSET_SIZE = 80  # Number of test records to evaluate (fits rate limits)
RATE_LIMIT_RPM = 10  # Gemini rate limit: requests per minute (common for all Gemini models)

# Path configuration
BASE_DIR = ROOT
DATA_DIR = BASE_DIR / "finetuning" / "data" / "processed" / "splits"
EVAL_DIR = BASE_DIR / "finetuning" / "evaluation" / "results"
EVAL_DIR.mkdir(parents=True, exist_ok=True)

# Environment variables
NEO4J_URI = os.environ.get("NEO4J_URI", "bolt://localhost:7687")
NEO4J_USER = os.environ.get("NEO4J_USER", "neo4j")
NEO4J_PASSWORD = os.environ.get("NEO4J_PASSWORD", "")
GEMINI_API_KEY = os.environ.get("GOOGLE_API_KEY_ALT", "")

if not NEO4J_PASSWORD:
    raise ValueError("NEO4J_PASSWORD environment variable not set")
if not GEMINI_API_KEY:
    raise ValueError("GEMINI_API_KEY environment variable not set")

print(f"Base directory: {BASE_DIR}")
print(f"Data directory: {DATA_DIR}")
print(f"Evaluation directory: {EVAL_DIR}")
print(f"Test subset size: {TEST_SUBSET_SIZE}")
print(f"Models to evaluate: {MODELS_TO_RUN}")
# Out:
# Project root: C:\Users\ishui\Desktop\OncoGraph\OncoGraph Agent
# Current working directory: c:\Users\ishui\Desktop\OncoGraph\OncoGraph Agent\finetuning\notebooks
# src module verified at: C:\Users\ishui\Desktop\OncoGraph\OncoGraph Agent\src
# Base directory: C:\Users\ishui\Desktop\OncoGraph\OncoGraph Agent
# Data directory: C:\Users\ishui\Desktop\OncoGraph\OncoGraph Agent\finetuning\data\processed\splits
# Evaluation directory: C:\Users\ishui\Desktop\OncoGraph\OncoGraph Agent\finetuning\evaluation\results
# Test subset size: 80
# Models to evaluate: ['gemini-2.0-flash']

# %%
# Helper Functions

from collections import Counter


def load_test_set(n: int) -> list[dict[str, Any]]:
    """Load test set and optionally sample n records with stratified sampling."""
    test_file = DATA_DIR / "test_sample.jsonl"
    if not test_file.exists():
        raise FileNotFoundError(f"Test file not found: {test_file}")

    records = []
    with test_file.open("r", encoding="utf-8") as f:
        for line in f:
            records.append(json.loads(line))

    if n >= len(records):
        return records

    # Stratified sampling by template_id
    records_by_template = defaultdict(list)
    for record in records:
        records_by_template[record["template_id"]].append(record)

    sampled = []
    for _template_id, template_records in records_by_template.items():
        num_to_sample = max(1, int(len(template_records) * (n / len(records))))
        if num_to_sample > len(template_records):
            num_to_sample = len(template_records)
        sampled.extend(template_records[:num_to_sample])

    # If we still need more, randomly sample remaining
    if len(sampled) < n:
        remaining = [r for r in records if r not in sampled]
        import random

        random.seed(42)
        additional = random.sample(remaining, n - len(sampled))
        sampled.extend(additional)

    return sampled[:n]


def extract_partial_matches(results: list[dict[str, Any]], model_name: str) -> list[dict[str, Any]]:
    """Extract records where syntactic and execution pass but result doesn't match."""
    partial = []
    for r in results:
        if r["syntactic_valid"] and r["execution_success"] and not r["result_match"]:
            partial.append(
                {
                    "id": r["id"],
                    "question": r["question"],
                    "gold_cypher": r["gold_cypher"],
                    "generated_cypher": r["generated_cypher"],
                    "gold_rows": r.get("gold_rows", []),
                    "generated_rows": r.get("generated_rows", []),
                    "error": r.get("error"),
                }
            )
    return partial


def create_inspection_summary(results: list[dict[str, Any]], model_name: str) -> pd.DataFrame:
    """Create a readable summary DataFrame from results."""
    summary_data = []
    for r in results:
        error_val = r.get("error") or ""
        question_val = r.get("question") or ""

        summary_data.append(
            {
                "id": r.get("id", ""),
                "question": question_val,
                "syntactic_valid": "✓" if r.get("syntactic_valid") else "✗",
                "execution_success": "✓" if r.get("execution_success") else "✗",
                "result_match": "✓" if r.get("result_match") else "✗",
                "gold_rows": len(r.get("gold_rows", [])),
                "gen_rows": len(r.get("generated_rows", [])),
                "error": error_val,
            }
        )
    return pd.DataFrame(summary_data)


def inspect_record(record: dict[str, Any], max_rows_display: int = 20):
    """Pretty-print a record for detailed inspection."""
    print("=" * 100)
    print(f"ID: {record.get('id', 'N/A')}")
    print(f"Question: {record.get('question', 'N/A')}")
    print("\n" + "-" * 100)

    if record.get("error"):
        print(f"ERROR: {record.get('error')}")

    gold_cypher = record.get("gold_cypher", "")
    gen_cypher = record.get("generated_cypher", "")
    gold_rows = record.get("gold_rows", [])
    gen_rows = record.get("generated_rows", [])

    print("\n" + "=" * 100)
    print("📋 GOLD CYPHER (Expected Reference)")
    print("=" * 100)
    if gold_cypher:
        print("```cypher")
        for line in gold_cypher.split("\n"):
            print(line)
        print("```")
    else:
        print("  (empty)")

    print(f"\n📊 GOLD RESULTS: {len(gold_rows)} row(s)")
    print("-" * 100)
    if gold_rows:
        for i, row in enumerate(gold_rows[:max_rows_display], 1):
            row_str = ", ".join([f"{k}={v!r}" for k, v in row.items()])
            print(f"  [{i:3d}] {row_str}")
        if len(gold_rows) > max_rows_display:
            print(f"  ... ({len(gold_rows) - max_rows_display} more rows)")
    else:
        print("  (no results)")

    print("\n" + "=" * 100)
    print("🔧 GENERATED CYPHER (Model Output)")
    print("=" * 100)
    if gen_cypher:
        print("```cypher")
        for line in gen_cypher.split("\n"):
            print(line)
        print("```")
    else:
        print("  (empty)")

    print(f"\n📊 GENERATED RESULTS: {len(gen_rows)} row(s)")
    print("-" * 100)
    if gen_rows:
        for i, row in enumerate(gen_rows[:max_rows_display], 1):
            row_str = ", ".join([f"{k}={v!r}" for k, v in row.items()])
            print(f"  [{i:3d}] {row_str}")
        if len(gen_rows) > max_rows_display:
            print(f"  ... ({len(gen_rows) - max_rows_display} more rows)")
    else:
        print("  (no results)")

    print("\n")


print("Helper functions loaded successfully")
# Out:
# Helper functions loaded successfully

# %%
# Import Evaluation Harness and Model Adapters

from finetuning.evaluation import (
    Evaluator,
    GeminiModelAdapter,
    ModelAdapter,
    QwenModelAdapter,
    run_evaluation,
)

print("Evaluation harness and model adapters imported successfully")
# Out:
# Evaluation harness and model adapters imported successfully

# %%
# Load Test Set

test_records = load_test_set(TEST_SUBSET_SIZE)
print(f"Loaded {len(test_records)} test records")
print("Template distribution:")
template_counts = Counter(r["template_id"] for r in test_records)
for template_id, count in sorted(template_counts.items()):
    print(f"  {template_id}: {count}")
# Out:
# Loaded 80 test records
# Template distribution:
#   f1_1_targets_gene: 2
#   f1_2_genes_for_therapy: 3
#   f1_3_gene_of_variant: 2
#   f1_4_variants_of_gene: 2
#   f2_1_targets_properties: 2
#   f2_2_gene_affects_therapy_disease: 5
#   f2_2_gene_affects_therapy_disease_resistance: 4
#   f2_2_gene_affects_therapy_disease_sensitivity: 5
#   f2_2_variant_affects_therapy_disease: 5
#   f2_2_variant_token_affects_therapy_disease: 5
#   f2_3_evidential_pmids_variant_resistance: 2
#   f2_3_evidential_pmids_variant_sensitivity: 2
#   f2_4_variant_node_property: 2
#   f3_1_therapies_union_genes: 1
#   f3_2_therapies_intersection_genes: 2
#   f3_3_therapies_target_a_not_b: 2
#   f4_1_target_validation_gene_disease: 4
#   f4_2_alternative_therapies_from_resistance_genes: 4
#   f5_1_biomarkers_in_disease: 3
#   f5_2_therapies_with_biomarker_evidence_in_disease: 4
#   f6_1_resistance_genes_for_union_therapies_in_disease: 4
#   f6_2_therapies_target_gene_not_other_with_disease_evidence: 6
#   f6_3_therapies_target_gene_with_variant_resistance_in_disease: 4
#   f6_4_alternative_therapies_for_resistance_in_disease: 5

# %%
# Initialize Shared Components

config = PipelineConfig()
validator = RuleBasedValidator(config=config)
executor = Neo4jExecutor(
    uri=NEO4J_URI,
    user=NEO4J_USER,
    password=NEO4J_PASSWORD,
    config=config,
)

print("Shared components initialized (validator, executor)")
# Out:
# Shared components initialized (validator, executor)

# %%
# Run Evaluations for All Models


def create_model_adapter(model_id: str) -> ModelAdapter:
    """Factory function to create the appropriate model adapter."""
    if model_id.startswith("gemini"):
        return GeminiModelAdapter(
            model=model_id,
            api_key=GEMINI_API_KEY,
            temperature=0.1,
            rate_limit_rpm=RATE_LIMIT_RPM,
        )
    elif model_id.startswith("qwen"):
        return QwenModelAdapter()
    else:
        raise ValueError(f"Unknown model: {model_id}")


# Store all results
all_results: dict[str, list[dict[str, Any]]] = {}
all_metrics: dict[str, dict[str, Any]] = {}

# Run evaluation for each model
for model_id in MODELS_TO_RUN:
    print(f"\n{'='*80}")
    print(f"Evaluating: {model_id}")
    print(f"{'='*80}")

    # Create model adapter
    adapter = create_model_adapter(model_id)

    # Create evaluator for this adapter
    evaluator = Evaluator(validator, executor, adapter)

    # Create checkpoint file path
    checkpoint_file = EVAL_DIR / f"{model_id}_checkpoint.jsonl"

    # Run evaluation
    results = run_evaluation(
        model_adapter=adapter,
        test_records=test_records,
        checkpoint_file=checkpoint_file,
        evaluator=evaluator,
        checkpoint_interval=5,
    )

    # Store results and compute metrics
    all_results[model_id] = results
    all_metrics[model_id] = evaluator.aggregate_metrics(results)

    # Print metrics
    print(f"\n{model_id} Metrics:")
    for key, value in all_metrics[model_id].items():
        print(f"  {key}: {value:.2f}" if isinstance(value, float) else f"  {key}: {value}")

print(f"\n{'='*80}")
print("All evaluations complete!")
print(f"{'='*80}")
# Out:
# ================================================================================
# Evaluating: gemini-2.0-flash
# ================================================================================
# Loading checkpoint from C:\Users\ishui\Desktop\OncoGraph\OncoGraph Agent\finetuning\evaluation\results\gemini-2.0-flash_checkpoint.jsonl
# Resuming from checkpoint: 65 already processed, 15 remaining
# Evaluating gemini-2.0-flash:  13%|█▎        | 2/15 [00:05<00:41,  3.16s/it]WARNING:root:Gemini API call failed: {'attempt': 1, 'total_attempts': 3, 'exception_type': 'ClientError', 'exception_message': "429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'model': 'gemini-2.0-flash', 'prompt_length': 14435, 'details': "{'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'code': '429'}
# Evaluating gemini-2.0-flash:  27%|██▋       | 4/15 [00:24<01:24,  7.73s/it]WARNING:root:Gemini API call failed: {'attempt': 1, 'total_attempts': 3, 'exception_type': 'ClientError', 'exception_message': "429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'model': 'gemini-2.0-flash', 'prompt_length': 15137, 'details': "{'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'code': '429'}
# Evaluating gemini-2.0-flash:  33%|███▎      | 5/15 [00:37<01:34,  9.47s/it]
# Checkpoint saved: 70 records processed
# Evaluating gemini-2.0-flash:  53%|█████▎    | 8/15 [00:57<00:54,  7.78s/it]WARNING:root:Gemini API call failed: {'attempt': 1, 'total_attempts': 3, 'exception_type': 'ClientError', 'exception_message': "429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\\nPlease retry in 43.707555686s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '43s'}]}}", 'model': 'gemini-2.0-flash', 'prompt_length': 12919, 'details': "{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\\nPlease retry in 43.707555686s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '43s'}]}}", 'code': '429'}
# WARNING:root:Gemini API call failed: {'attempt': 2, 'total_attempts': 3, 'exception_type': 'ClientError', 'exception_message': "429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\\nPlease retry in 42.562384443s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '42s'}]}}", 'model': 'gemini-2.0-flash', 'prompt_length': 12919, 'details': "{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\\nPlease retry in 42.562384443s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '42s'}]}}", 'code': '429'}
# WARNING:root:Gemini API call failed: {'attempt': 3, 'total_attempts': 3, 'exception_type': 'ClientError', 'exception_message': "429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\\nPlease retry in 40.425368981s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '40s'}]}}", 'model': 'gemini-2.0-flash', 'prompt_length': 12919, 'details': "{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\\nPlease retry in 40.425368981s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '40s'}]}}", 'code': '429'}
# Rate limit hit. API recommends retry in 40.4s. Waiting 41.4s...
# Evaluating gemini-2.0-flash:  67%|██████▋   | 10/15 [02:04<01:34, 18.98s/it]
# Checkpoint saved: 75 records processed
# WARNING:root:Gemini API call failed: {'attempt': 1, 'total_attempts': 3, 'exception_type': 'ClientError', 'exception_message': "429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'model': 'gemini-2.0-flash', 'prompt_length': 14842, 'details': "{'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'code': '429'}
# Evaluating gemini-2.0-flash:  80%|████████  | 12/15 [02:31<00:49, 16.42s/it]WARNING:root:Gemini API call failed: {'attempt': 1, 'total_attempts': 3, 'exception_type': 'ClientError', 'exception_message': "429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'model': 'gemini-2.0-flash', 'prompt_length': 14690, 'details': "{'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'code': '429'}
# WARNING:root:Gemini API call failed: {'attempt': 2, 'total_attempts': 3, 'exception_type': 'ClientError', 'exception_message': "429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'model': 'gemini-2.0-flash', 'prompt_length': 14690, 'details': "{'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'code': '429'}
# Evaluating gemini-2.0-flash:  87%|████████▋ | 13/15 [02:46<00:31, 15.93s/it]WARNING:root:Gemini API call failed: {'attempt': 1, 'total_attempts': 3, 'exception_type': 'ClientError', 'exception_message': "429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'model': 'gemini-2.0-flash', 'prompt_length': 14809, 'details': "{'error': {'code': 429, 'message': 'Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.', 'status': 'RESOURCE_EXHAUSTED'}}", 'code': '429'}
# Evaluating gemini-2.0-flash: 100%|██████████| 15/15 [03:15<00:00, 13.03s/it]
# Checkpoint saved: 80 records processed
#
# gemini-2.0-flash evaluation complete: 80 records
#
# gemini-2.0-flash Metrics:
#   total: 80
#   syntactic_validity_pct: 97.50
#   execution_success_pct: 89.74
#   semantic_accuracy_pct: 54.29
#   avg_latency_ms: 14558.57
#   avg_tokens_per_second: 24998.56
#   avg_input_tokens: 7075.80
#   avg_output_tokens: 233.15
#   total_input_tokens: 566064
#   total_output_tokens: 18652
#
# ================================================================================
# All evaluations complete!
# ================================================================================

# %%
# Load Results from Checkpoints (if notebook was restarted)

# If all_results is not defined or empty, load from checkpoints
if "all_results" not in globals() or not all_results:
    print("Loading results from checkpoint files...")
    all_results = {}
    all_metrics = {}

    for model_id in MODELS_TO_RUN:
        checkpoint_file = EVAL_DIR / f"{model_id}_checkpoint.jsonl"
        if checkpoint_file.exists():
            with checkpoint_file.open("r", encoding="utf-8") as f:
                results = [json.loads(line) for line in f]
                all_results[model_id] = results

                # Create a dummy adapter to get evaluator for metrics
                adapter = create_model_adapter(model_id)
                evaluator = Evaluator(validator, executor, adapter)
                all_metrics[model_id] = evaluator.aggregate_metrics(results)
                print(f"  Loaded {len(results)} results for {model_id}")
        else:
            print(f"  No checkpoint found for {model_id}")

print(f"\nAvailable model results: {list(all_results.keys())}")
# Out:
# Available model results: ['gemini-2.0-flash']

# %%
# Results Analysis & Comparison

if not all_results:
    raise ValueError("No results available. Run Cell 6 to evaluate models first.")

# Create comparison table for all evaluated models
comparison_data = {
    "Metric": [
        "Syntactic Validity (%)",
        "Execution Success (%)",
        "Output Accuracy (%)",
        "Avg Latency (ms)",
        "Avg Input Tokens",
        "Avg Output Tokens",
        "Total Input Tokens",
        "Total Output Tokens",
    ],
}

# Add a column for each model
for model_id, metrics in all_metrics.items():
    comparison_data[model_id] = [
        metrics.get("syntactic_validity_pct", 0),
        metrics.get("execution_success_pct", 0),
        metrics.get("output_accuracy_pct", 0),
        metrics.get("avg_latency_ms", 0),
        metrics.get("avg_input_tokens", 0),
        metrics.get("avg_output_tokens", 0),
        metrics.get("total_input_tokens", 0),
        metrics.get("total_output_tokens", 0),
    ]

df_comparison = pd.DataFrame(comparison_data)
print("\n" + "=" * 80)
print("BASELINE EVALUATION COMPARISON")
print("=" * 80)
print(df_comparison.to_string(index=False))
print("\n")

# Save summaries per model
for model_id, results in all_results.items():
    summary = create_inspection_summary(results, model_id)
    summary_file = EVAL_DIR / f"{model_id}_summary.csv"
    summary.to_csv(summary_file, index=False)
    print(f"  {model_id} summary saved to: {summary_file}")
# Out:
# ================================================================================
# BASELINE EVALUATION COMPARISON
# ================================================================================
#                 Metric  gemini-2.0-flash
# Syntactic Validity (%)         97.500000
#  Execution Success (%)         89.743590
#  Semantic Accuracy (%)         54.285714
#       Avg Latency (ms)      14558.572985
#       Avg Input Tokens       7075.800000
#      Avg Output Tokens        233.150000
#     Total Input Tokens     566064.000000
#    Total Output Tokens      18652.000000
#
#
#   gemini-2.0-flash summary saved to: C:\Users\ishui\Desktop\OncoGraph\OncoGraph Agent\finetuning\evaluation\results\gemini-2.0-flash_summary.csv

# %%
# Identify Partial Matches for All Models

all_partial_matches = {}

for model_id, results in all_results.items():
    partial = extract_partial_matches(results, model_id)
    all_partial_matches[model_id] = partial

    # Save partial matches for inspection
    partial_file = EVAL_DIR / f"partial_matches_{model_id}.jsonl"
    with partial_file.open("w", encoding="utf-8") as f:
        for record in partial:
            f.write(json.dumps(record, ensure_ascii=False) + "\n")

    print(f"  {model_id}: {len(partial)} partial matches")

print("\nPartial matches saved:")
for model_id, partial in all_partial_matches.items():
    print(f"  {EVAL_DIR / f'partial_matches_{model_id}.jsonl'}")
# Out:
#   gemini-2.0-flash: 32 partial matches
#
# Partial matches saved:
#   C:\Users\ishui\Desktop\OncoGraph\OncoGraph Agent\finetuning\evaluation\results\partial_matches_gemini-2.0-flash.jsonl

# %%
# Display Detailed Inspection for All Models

for model_id, partial_matches in all_partial_matches.items():
    if partial_matches:
        print("\n" + "=" * 100)
        print(f"DETAILED INSPECTION: {model_id.upper()} PARTIAL MATCHES (syntax + exec pass, result mismatch)")
        print("=" * 100)
        for i, record in enumerate(partial_matches[:10]):
            print(f"\n--- Mismatch #{i} ({model_id}) ---")
            inspect_record(record)
# Out:
# ====================================================================================================
# DETAILED INSPECTION: GEMINI-2.0-FLASH PARTIAL MATCHES (syntax + exec pass, result mismatch)
# ====================================================================================================
#
# --- Mismatch #0 (gemini-2.0-flash) ---
# ====================================================================================================
# ID: F3.2-000005-P1
# Question: Which drugs target both ALK and EML4?
#
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# 📋 GOLD CYPHER (Expected Reference)
# ====================================================================================================
# ```cypher
# MATCH (t:Therapy)-[r1:TARGETS]->(g1:Gene)
# WHERE toLower(g1.symbol) = toLower('ALK')
#    OR any(s IN coalesce(g1.synonyms, []) WHERE toLower(s) = toLower('ALK'))
# MATCH (t)-[r2:TARGETS]->(g2:Gene)
# WHERE toLower(g2.symbol) = toLower('EML4')
#    OR any(s IN coalesce(g2.synonyms, []) WHERE toLower(s) = toLower('EML4'))
# RETURN
#   g1.symbol AS gene_symbol,
#   t.name AS therapy_name,
#   r1.moa AS targets_moa,
#   coalesce(r1.ref_sources, []) AS ref_sources,
#   coalesce(r1.ref_ids, []) AS ref_ids,
#   coalesce(r1.ref_urls, []) AS ref_urls
# LIMIT 100
#
# ```
#
# 📊 GOLD RESULTS: 4 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] gene_symbol='ALK', therapy_name='Alectinib', targets_moa='ALK tyrosine kinase receptor inhibitor | EML4-ALK', ref_sources=['FDA', 'FDA'], ref_ids=['label/2015/208434s000lbl.pdf', 'nda/2015/208434Orig1s000ClinPharmR.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2015/208434s000lbl.pdf', 'https://www.accessdata.fda.gov/drugsatfda_docs/nda/2015/208434Orig1s000ClinPharmR.pdf']
#   [  2] gene_symbol='ALK', therapy_name='Ceritinib', targets_moa='ALK tyrosine kinase receptor inhibitor | EML4-ALK | NPM/ALK (Nucleophosmin/ALK tyrosine kinase receptor)', ref_sources=['FDA', 'FDA'], ref_ids=['label/2014/205755s000lbl.pdf', 'label/2017/205755s009lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2014/205755s000lbl.pdf', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2017/205755s009lbl.pdf']
#   [  3] gene_symbol='ALK', therapy_name='Crizotinib', targets_moa='ALK tyrosine kinase receptor inhibitor | EML4-ALK | NPM/ALK (Nucleophosmin/ALK tyrosine kinase receptor)', ref_sources=['FDA', 'FDA'], ref_ids=['label/2012/202570s003lbl.pdf', 'label/2017/202570s021lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2012/202570s003lbl.pdf', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2017/202570s021lbl.pdf']
#   [  4] gene_symbol='ALK', therapy_name='Lorlatinib', targets_moa='ALK tyrosine kinase receptor inhibitor | EML4-ALK  inhibitor', ref_sources=['FDA'], ref_ids=['label/2018/210868s000lbl.pdf'], ref_urls=['https://www.accessdata.fda.gov/drugsatfda_docs/label/2018/210868s000lbl.pdf']
#
# ====================================================================================================
# 🔧 GENERATED CYPHER (Model Output)
# ====================================================================================================
# ```cypher
# MATCH (t:Therapy)-[:TARGETS]->(g1:Gene)
# WHERE toLower(g1.symbol) = toLower('ALK')
#    OR any(s IN coalesce(g1.synonyms, []) WHERE toLower(s) = toLower('ALK'))
# MATCH (t)-[:TARGETS]->(g2:Gene)
# WHERE toLower(g2.symbol) = toLower('EML4')
#    OR any(s IN coalesce(g2.synonyms, []) WHERE toLower(s) = toLower('EML4'))
# RETURN t.name AS therapy_name
# LIMIT 100
# ```
#
# 📊 GENERATED RESULTS: 4 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] therapy_name='Alectinib'
#   [  2] therapy_name='Ceritinib'
#   [  3] therapy_name='Crizotinib'
#   [  4] therapy_name='Lorlatinib'
#
#
#
# --- Mismatch #1 (gemini-2.0-flash) ---
# ====================================================================================================
# ID: F3.1-000046-P3
# Question: Show treatments that target FGFR2 or FGFR3.
#
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# 📋 GOLD CYPHER (Expected Reference)
# ====================================================================================================
# ```cypher
# MATCH (t:Therapy)-[r:TARGETS]->(g:Gene)
# WHERE (
#   toLower(g.symbol) = toLower('FGFR2')
#   OR any(s IN coalesce(g.synonyms, []) WHERE toLower(s) = toLower('FGFR2'))
#   OR toLower(g.symbol) = toLower('FGFR3')
#   OR any(s IN coalesce(g.synonyms, []) WHERE toLower(s) = toLower('FGFR3'))
# )
# RETURN
#   g.symbol AS gene_symbol,
#   t.name AS therapy_name,
#   r.moa AS targets_moa,
#   coalesce(r.ref_sources, []) AS ref_sources,
#   coalesce(r.ref_ids, []) AS ref_ids,
#   coalesce(r.ref_urls, []) AS ref_urls
# LIMIT 100
#
# ```
#
# 📊 GOLD RESULTS: 24 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] gene_symbol='FGFR2', therapy_name='AZD-4547', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['http://openinnovation.astrazeneca.com/what-we-offer/compound/azd4547/', '22369928'], ref_urls=['http://europepmc.org/abstract/MED/22369928', 'http://openinnovation.astrazeneca.com/what-we-offer/compound/azd4547/']
#   [  2] gene_symbol='FGFR2', therapy_name='Derazantinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['Other', 'Other'], ref_ids=['http://meetinglibrary.asco.org/content/149025-156', 'http://www.arqule.com/res/pip/'], ref_urls=['http://meetinglibrary.asco.org/content/149025-156', 'http://www.arqule.com/res/pip/']
#   [  3] gene_symbol='FGFR2', therapy_name='Erdafitinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2019/212018s000lbl.pdf'], ref_urls=['https://www.accessdata.fda.gov/drugsatfda_docs/label/2019/212018s000lbl.pdf']
#   [  4] gene_symbol='FGFR2', therapy_name='Futibatinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['https://cancerres.aacrjournals.org/content/80/22/4986', '33054456'], ref_urls=['http://europepmc.org/abstract/MED/33054456', 'https://cancerres.aacrjournals.org/content/80/22/4986']
#   [  5] gene_symbol='FGFR2', therapy_name='Infigratinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['FDA', 'Other', 'PubMed'], ref_ids=['label/2021/214622s000lbl.pdf', 'http://www.novartisoncology.com/ct/pipelineDetails?compound=BGJ398&diseaseAcr=GBM', '21936542'], ref_urls=['http://europepmc.org/abstract/MED/21936542', 'http://www.novartisoncology.com/ct/pipelineDetails?compound=BGJ398&diseaseAcr=GBM', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2021/214622s000lbl.pdf']
#   [  6] gene_symbol='FGFR2', therapy_name='Lucitanib', targets_moa='Fibroblast growth factor receptor 2 inhibitor', ref_sources=['Other', 'PubMed', 'PubMed'], ref_ids=['http://bit.ly/1ZGqyT3', '21212416', '22304225'], ref_urls=['http://bit.ly/1ZGqyT3', 'http://europepmc.org/abstract/MED/21212416', 'http://europepmc.org/abstract/MED/22304225']
#   [  7] gene_symbol='FGFR2', therapy_name='Nintedanib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2014/205832s000lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2014/205832s000lbl.pdf']
#   [  8] gene_symbol='FGFR2', therapy_name='Pemigatinib', targets_moa='Fibroblast growth factor receptor 2 inhibitor', ref_sources=['FDA'], ref_ids=['label/2020/213736s000lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2020/213736s000lbl.pdf']
#   [  9] gene_symbol='FGFR2', therapy_name='Regorafenib', targets_moa='Fibroblast growth factor receptor 2 inhibitor', ref_sources=['Expert', 'FDA'], ref_ids=['REGORAFENIB', 'label/2012/203085lbl.pdf'], ref_urls=['http://chembl.blogspot.co.uk/search?q=REGORAFENIB', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2012/203085lbl.pdf']
#   [ 10] gene_symbol='FGFR2', therapy_name='Regorafenib Anhydrous', targets_moa='Fibroblast growth factor receptor 2 inhibitor', ref_sources=['Expert', 'FDA'], ref_ids=['REGORAFENIB', 'label/2012/203085lbl.pdf'], ref_urls=['http://chembl.blogspot.co.uk/search?q=REGORAFENIB', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2012/203085lbl.pdf']
#   [ 11] gene_symbol='FGFR2', therapy_name='Rogaratinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['DOI'], ref_ids=['10.1158/1538-7445.AM2014-1739'], ref_urls=['http://cancerres.aacrjournals.org/content/74/19_Supplement/1739']
#   [ 12] gene_symbol='FGFR2', therapy_name='TRK Inhibitor', targets_moa='Fibroblast growth factor receptor 2 inhibitor', ref_sources=['Expert', 'FDA'], ref_ids=['REGORAFENIB', 'label/2012/203085lbl.pdf'], ref_urls=['http://chembl.blogspot.co.uk/search?q=REGORAFENIB', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2012/203085lbl.pdf']
#   [ 13] gene_symbol='FGFR2', therapy_name='Tyrosine Kinase Inhibitor', targets_moa='Fibroblast growth factor receptor 2 inhibitor', ref_sources=['ClinicalTrials', 'PubMed'], ref_ids=['NCT01948297', '25169980'], ref_urls=['http://europepmc.org/abstract/MED/25169980', 'https://www.clinicaltrials.gov/ct2/show/NCT01948297']
#   [ 14] gene_symbol='FGFR3', therapy_name='AZD-4547', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['http://openinnovation.astrazeneca.com/what-we-offer/compound/azd4547/', '22369928'], ref_urls=['http://europepmc.org/abstract/MED/22369928', 'http://openinnovation.astrazeneca.com/what-we-offer/compound/azd4547/']
#   [ 15] gene_symbol='FGFR3', therapy_name='Derazantinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['Other', 'Other'], ref_ids=['http://meetinglibrary.asco.org/content/149025-156', 'http://www.arqule.com/res/pip/'], ref_urls=['http://meetinglibrary.asco.org/content/149025-156', 'http://www.arqule.com/res/pip/']
#   [ 16] gene_symbol='FGFR3', therapy_name='Dovitinib', targets_moa='Fibroblast growth factor receptor 3 inhibitor', ref_sources=['PubMed'], ref_ids=['15897558'], ref_urls=['http://europepmc.org/abstract/MED/15897558']
#   [ 17] gene_symbol='FGFR3', therapy_name='Erdafitinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2019/212018s000lbl.pdf'], ref_urls=['https://www.accessdata.fda.gov/drugsatfda_docs/label/2019/212018s000lbl.pdf']
#   [ 18] gene_symbol='FGFR3', therapy_name='Futibatinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['https://cancerres.aacrjournals.org/content/80/22/4986', '33054456'], ref_urls=['http://europepmc.org/abstract/MED/33054456', 'https://cancerres.aacrjournals.org/content/80/22/4986']
#   [ 19] gene_symbol='FGFR3', therapy_name='Infigratinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['FDA', 'Other', 'PubMed'], ref_ids=['label/2021/214622s000lbl.pdf', 'http://www.novartisoncology.com/ct/pipelineDetails?compound=BGJ398&diseaseAcr=GBM', '21936542'], ref_urls=['http://europepmc.org/abstract/MED/21936542', 'http://www.novartisoncology.com/ct/pipelineDetails?compound=BGJ398&diseaseAcr=GBM', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2021/214622s000lbl.pdf']
#   [ 20] gene_symbol='FGFR3', therapy_name='Nintedanib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2014/205832s000lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2014/205832s000lbl.pdf']
#   ... (4 more rows)
#
# ====================================================================================================
# 🔧 GENERATED CYPHER (Model Output)
# ====================================================================================================
# ```cypher
# MATCH (t:Therapy)-[r:TARGETS]->(g:Gene)
# WHERE toLower(g.symbol) = toLower('FGFR2')
#    OR any(s IN coalesce(g.synonyms, []) WHERE toLower(s) = toLower('FGFR2'))
# WITH t, g, r
# MATCH (t)-[r2:TARGETS]->(g2:Gene)
# WHERE toLower(g2.symbol) = toLower('FGFR3')
#    OR any(s IN coalesce(g2.synonyms, []) WHERE toLower(s) = toLower('FGFR3'))
# RETURN
#   g.symbol AS gene_symbol,
#   t.name AS therapy_name,
#   r.moa AS targets_moa,
#   coalesce(r.ref_sources, []) AS ref_sources,
#   coalesce(r.ref_ids, []) AS ref_ids,
#   coalesce(r.ref_urls, []) AS ref_urls
# LIMIT 100
# ```
#
# 📊 GENERATED RESULTS: 9 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] gene_symbol='FGFR2', therapy_name='AZD-4547', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['http://openinnovation.astrazeneca.com/what-we-offer/compound/azd4547/', '22369928'], ref_urls=['http://europepmc.org/abstract/MED/22369928', 'http://openinnovation.astrazeneca.com/what-we-offer/compound/azd4547/']
#   [  2] gene_symbol='FGFR2', therapy_name='Derazantinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['Other', 'Other'], ref_ids=['http://meetinglibrary.asco.org/content/149025-156', 'http://www.arqule.com/res/pip/'], ref_urls=['http://meetinglibrary.asco.org/content/149025-156', 'http://www.arqule.com/res/pip/']
#   [  3] gene_symbol='FGFR2', therapy_name='Erdafitinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2019/212018s000lbl.pdf'], ref_urls=['https://www.accessdata.fda.gov/drugsatfda_docs/label/2019/212018s000lbl.pdf']
#   [  4] gene_symbol='FGFR2', therapy_name='Futibatinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['https://cancerres.aacrjournals.org/content/80/22/4986', '33054456'], ref_urls=['http://europepmc.org/abstract/MED/33054456', 'https://cancerres.aacrjournals.org/content/80/22/4986']
#   [  5] gene_symbol='FGFR2', therapy_name='Infigratinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['FDA', 'Other', 'PubMed'], ref_ids=['label/2021/214622s000lbl.pdf', 'http://www.novartisoncology.com/ct/pipelineDetails?compound=BGJ398&diseaseAcr=GBM', '21936542'], ref_urls=['http://europepmc.org/abstract/MED/21936542', 'http://www.novartisoncology.com/ct/pipelineDetails?compound=BGJ398&diseaseAcr=GBM', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2021/214622s000lbl.pdf']
#   [  6] gene_symbol='FGFR2', therapy_name='Nintedanib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2014/205832s000lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2014/205832s000lbl.pdf']
#   [  7] gene_symbol='FGFR2', therapy_name='Pemigatinib', targets_moa='Fibroblast growth factor receptor 2 inhibitor', ref_sources=['FDA'], ref_ids=['label/2020/213736s000lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2020/213736s000lbl.pdf']
#   [  8] gene_symbol='FGFR2', therapy_name='Rogaratinib', targets_moa='Fibroblast growth factor receptor inhibitor', ref_sources=['DOI'], ref_ids=['10.1158/1538-7445.AM2014-1739'], ref_urls=['http://cancerres.aacrjournals.org/content/74/19_Supplement/1739']
#   [  9] gene_symbol='FGFR2', therapy_name='Tyrosine Kinase Inhibitor', targets_moa='Fibroblast growth factor receptor 2 inhibitor', ref_sources=['ClinicalTrials', 'PubMed'], ref_ids=['NCT01948297', '25169980'], ref_urls=['http://europepmc.org/abstract/MED/25169980', 'https://www.clinicaltrials.gov/ct2/show/NCT01948297']
#
#
#
# --- Mismatch #2 (gemini-2.0-flash) ---
# ====================================================================================================
# ID: F4.2-000016-P2
# Question: Which drugs target biomarkers of resistance to Platinum Compound in Ovarian Serous Carcinoma?
#
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# 📋 GOLD CYPHER (Expected Reference)
# ====================================================================================================
# ```cypher
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t1:Therapy)
# WHERE (
#   toLower(t1.name) = toLower('Platinum Compound')
#   OR any(s IN coalesce(t1.synonyms, []) WHERE toLower(s) = toLower('Platinum Compound'))
#   OR toLower(t1.name) CONTAINS toLower('Platinum Compound')
# )
#   AND toLower(rel.effect) = 'resistance'
#   AND (
#     toLower(rel.disease_name) CONTAINS 'ovarian' AND
#     toLower(rel.disease_name) CONTAINS 'serous' AND
#     toLower(rel.disease_name) CONTAINS 'carcinoma'
#   )
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(g:Gene)
# WITH CASE WHEN b:Gene THEN b.symbol ELSE g.symbol END AS gene_symbol
# WHERE gene_symbol IS NOT NULL
# MATCH (t2:Therapy)-[r:TARGETS]->(tg:Gene)
# WHERE (
#   toLower(tg.symbol) = toLower(gene_symbol)
#   OR any(s IN coalesce(tg.synonyms, []) WHERE toLower(s) = toLower(gene_symbol))
# )
#   AND toLower(t2.name) <> toLower('Platinum Compound')
# RETURN
#   gene_symbol,
#   t2.name AS therapy_name,
#   r.moa AS targets_moa,
#   coalesce(r.ref_sources, []) AS ref_sources,
#   coalesce(r.ref_ids, []) AS ref_ids,
#   coalesce(r.ref_urls, []) AS ref_urls
# LIMIT 100
#
# ```
#
# 📊 GOLD RESULTS: 2 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] gene_symbol='AURKA', therapy_name='Alisertib', targets_moa='Serine/threonine-protein kinase Aurora-A inhibitor', ref_sources=['PubMed'], ref_ids=['22016509'], ref_urls=['http://europepmc.org/abstract/MED/22016509']
#   [  2] gene_symbol='AURKA', therapy_name='Tozasertib', targets_moa='Serine/threonine-protein kinase Aurora inhibitor', ref_sources=['PubMed', 'PubMed'], ref_ids=['14981513', '26345296'], ref_urls=['http://europepmc.org/abstract/MED/14981513', 'http://europepmc.org/abstract/MED/26345296']
#
# ====================================================================================================
# 🔧 GENERATED CYPHER (Model Output)
# ====================================================================================================
# ```cypher
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t:Therapy)
# WHERE toLower(rel.effect) = toLower('resistance')
# AND (toLower(t.name) CONTAINS toLower('platinum') OR any(tag IN coalesce(t.tags, []) WHERE toLower(tag) CONTAINS toLower('platinum')))
# AND toLower(rel.disease_name) CONTAINS toLower('ovarian')
# AND toLower(rel.disease_name) CONTAINS toLower('serous')
# AND toLower(rel.disease_name) CONTAINS toLower('carcinoma')
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(g:Gene)
# RETURN
#     CASE WHEN b:Variant THEN coalesce(b.name, b.hgvs_p) END AS variant_name,
#     CASE WHEN b:Gene THEN b.symbol ELSE g.symbol END AS gene_symbol,
#     t.name AS therapy_name,
#     rel.effect AS effect,
#     rel.disease_name AS disease_name,
#     coalesce(rel.pmids, []) AS pmids
# LIMIT 100
# ```
#
# 📊 GENERATED RESULTS: 1 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] variant_name='AURKA Overexpression', gene_symbol='AURKA', therapy_name='Platinum Compound', effect='resistance', disease_name='Ovarian Serous Carcinoma', pmids=['27209210']
#
#
#
# --- Mismatch #3 (gemini-2.0-flash) ---
# ====================================================================================================
# ID: F4.2-000184-P3
# Question: Find therapies that target resistance genes for Imatinib in Melanoma.
#
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# 📋 GOLD CYPHER (Expected Reference)
# ====================================================================================================
# ```cypher
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t1:Therapy)
# WHERE (
#   toLower(t1.name) = toLower('Imatinib')
#   OR any(s IN coalesce(t1.synonyms, []) WHERE toLower(s) = toLower('Imatinib'))
#   OR toLower(t1.name) CONTAINS toLower('Imatinib')
# )
#   AND toLower(rel.effect) = 'resistance'
#   AND (
#     toLower(rel.disease_name) CONTAINS 'melanoma'
#   )
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(g:Gene)
# WITH CASE WHEN b:Gene THEN b.symbol ELSE g.symbol END AS gene_symbol
# WHERE gene_symbol IS NOT NULL
# MATCH (t2:Therapy)-[r:TARGETS]->(tg:Gene)
# WHERE (
#   toLower(tg.symbol) = toLower(gene_symbol)
#   OR any(s IN coalesce(tg.synonyms, []) WHERE toLower(s) = toLower(gene_symbol))
# )
#   AND toLower(t2.name) <> toLower('Imatinib')
# RETURN
#   gene_symbol,
#   t2.name AS therapy_name,
#   r.moa AS targets_moa,
#   coalesce(r.ref_sources, []) AS ref_sources,
#   coalesce(r.ref_ids, []) AS ref_ids,
#   coalesce(r.ref_urls, []) AS ref_urls
# LIMIT 100
#
# ```
#
# 📊 GOLD RESULTS: 85 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] gene_symbol='KIT', therapy_name='Amuvatinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['Other', 'PubMed', 'PubMed'], ref_ids=['http://www.google.com/patents/US20080226747', '24326130', '25110867'], ref_urls=['http://europepmc.org/abstract/MED/24326130', 'http://europepmc.org/abstract/MED/25110867', 'http://www.google.com/patents/US20080226747']
#   [  2] gene_symbol='KIT', therapy_name='Avapritinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2020/212608s000lbl.pdf'], ref_urls=['https://www.accessdata.fda.gov/drugsatfda_docs/label/2020/212608s000lbl.pdf']
#   [  3] gene_symbol='KIT', therapy_name='C-Met Inhibitor', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['http://www.exelixis.com/pipeline/xl880', '19808973'], ref_urls=['http://europepmc.org/abstract/MED/19808973', 'http://www.exelixis.com/pipeline/xl880']
#   [  4] gene_symbol='KIT', therapy_name='Cediranib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['PubMed'], ref_ids=['15899831'], ref_urls=['http://europepmc.org/abstract/MED/15899831']
#   [  5] gene_symbol='KIT', therapy_name='Dasatinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['DailyMed', 'FDA'], ref_ids=['setid=0e7f054c-7a27-4192-bd1c-6115d8be858f#section-13', 'label/2010/021986s7s8lbl.pdf'], ref_urls=['http://dailymed.nlm.nih.gov/dailymed/lookup.cfm?setid=0e7f054c-7a27-4192-bd1c-6115d8be858f#section-13', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2010/021986s7s8lbl.pdf']
#   [  6] gene_symbol='KIT', therapy_name='Dovitinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['PubMed'], ref_ids=['15897558'], ref_urls=['http://europepmc.org/abstract/MED/15897558']
#   [  7] gene_symbol='KIT', therapy_name='Foretinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['http://www.exelixis.com/pipeline/xl880', '19808973'], ref_urls=['http://europepmc.org/abstract/MED/19808973', 'http://www.exelixis.com/pipeline/xl880']
#   [  8] gene_symbol='KIT', therapy_name='Imatinib Mesylate', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['DailyMed', 'FDA', 'Wikipedia'], ref_ids=['setid=211ef2da-2868-4a77-8055-1cb2cd78e24b#section-13', 'label/2008/021588s024lbl.pdf', 'Bcr-Abl_tyrosine-kinase_inhibitor'], ref_urls=['http://dailymed.nlm.nih.gov/dailymed/lookup.cfm?setid=211ef2da-2868-4a77-8055-1cb2cd78e24b#section-13', 'http://en.wikipedia.org/wiki/Bcr-Abl_tyrosine-kinase_inhibitor', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2008/021588s024lbl.pdf']
#   [  9] gene_symbol='KIT', therapy_name='Midostaurin', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['PubMed', 'PubMed'], ref_ids=['12124173', '16969355'], ref_urls=['http://europepmc.org/abstract/MED/12124173', 'http://europepmc.org/abstract/MED/16969355']
#   [ 10] gene_symbol='KIT', therapy_name='Motesanib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['PubMed'], ref_ids=['16951187'], ref_urls=['http://europepmc.org/abstract/MED/16951187']
#   [ 11] gene_symbol='KIT', therapy_name='Pazopanib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['DailyMed'], ref_ids=['setid=f5b7b3a4-c3a4-4722-8ca5-8f6a5c622553#section-14'], ref_urls=['http://dailymed.nlm.nih.gov/dailymed/lookup.cfm?setid=f5b7b3a4-c3a4-4722-8ca5-8f6a5c622553#section-14']
#   [ 12] gene_symbol='KIT', therapy_name='Pexidartinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['FDA', 'PubMed', 'PubMed'], ref_ids=['label/2019/211810s000lbl.pdf', '22039576', '25847190'], ref_urls=['http://europepmc.org/abstract/MED/22039576', 'http://europepmc.org/abstract/MED/25847190', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2019/211810s000lbl.pdf']
#   [ 13] gene_symbol='KIT', therapy_name='Quizartinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['PubMed', 'PubMed'], ref_ids=['19654408', '23497317'], ref_urls=['http://europepmc.org/abstract/MED/19654408', 'http://europepmc.org/abstract/MED/23497317']
#   [ 14] gene_symbol='KIT', therapy_name='Regorafenib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['Expert', 'FDA'], ref_ids=['REGORAFENIB', 'label/2012/203085lbl.pdf'], ref_urls=['http://chembl.blogspot.co.uk/search?q=REGORAFENIB', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2012/203085lbl.pdf']
#   [ 15] gene_symbol='KIT', therapy_name='Regorafenib Anhydrous', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['Expert', 'FDA'], ref_ids=['REGORAFENIB', 'label/2012/203085lbl.pdf'], ref_urls=['http://chembl.blogspot.co.uk/search?q=REGORAFENIB', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2012/203085lbl.pdf']
#   [ 16] gene_symbol='KIT', therapy_name='Ripretinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2020/213973s000lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2020/213973s000lbl.pdf']
#   [ 17] gene_symbol='KIT', therapy_name='Sorafenib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2011/021923s012lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2011/021923s012lbl.pdf']
#   [ 18] gene_symbol='KIT', therapy_name='Sorafenib Tosylate', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2011/021923s012lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2011/021923s012lbl.pdf']
#   [ 19] gene_symbol='KIT', therapy_name='Sunitinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['DailyMed', 'EMA'], ref_ids=['setid=43a4d7f8-48ae-4a63-9108-2fa8e3ea9d9c#section-14', 'https://www.ema.europa.eu/en/documents/product-information/sunitinib-accord-epar-product-information_en.pdf'], ref_urls=['http://dailymed.nlm.nih.gov/dailymed/lookup.cfm?setid=43a4d7f8-48ae-4a63-9108-2fa8e3ea9d9c#section-14', 'https://www.ema.europa.eu/en/documents/product-information/sunitinib-accord-epar-product-information_en.pdf']
#   [ 20] gene_symbol='KIT', therapy_name='TRK Inhibitor', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['Expert', 'FDA'], ref_ids=['REGORAFENIB', 'label/2012/203085lbl.pdf'], ref_urls=['http://chembl.blogspot.co.uk/search?q=REGORAFENIB', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2012/203085lbl.pdf']
#   ... (65 more rows)
#
# ====================================================================================================
# 🔧 GENERATED CYPHER (Model Output)
# ====================================================================================================
# ```cypher
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t:Therapy)
# WHERE (
#     toLower(t.name) = toLower('imatinib')
#     OR any(s IN coalesce(t.synonyms, []) WHERE toLower(s) = toLower('imatinib'))
#     OR toLower(t.name) CONTAINS toLower('imatinib')
#   )
#   AND toLower(rel.effect) = 'resistance'
#   AND toLower(rel.disease_name) CONTAINS toLower('melanoma')
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(g:Gene)
# RETURN
#   CASE WHEN b:Variant THEN coalesce(b.name, b.hgvs_p) END AS variant_name,
#   CASE WHEN b:Gene THEN b.symbol ELSE g.symbol END AS gene_symbol,
#   t.name AS therapy_name,
#   rel.effect AS effect,
#   rel.disease_name AS disease_name,
#   coalesce(rel.pmids, []) AS pmids
# LIMIT 100
# ```
#
# 📊 GENERATED RESULTS: 4 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] variant_name='KIT Amplification', gene_symbol='KIT', therapy_name='Imatinib', effect='resistance', disease_name='Mucosal Melanoma', pmids=['23775962']
#   [  2] variant_name='KIT D820Y', gene_symbol='KIT', therapy_name='Imatinib', effect='resistance', disease_name='Melanoma', pmids=['21642685']
#   [  3] variant_name='KIT L576P', gene_symbol='KIT', therapy_name='Imatinib', effect='resistance', disease_name='Melanoma', pmids=['19671763']
#   [  4] variant_name='PDGFRA V658A', gene_symbol='PDGFRA', therapy_name='Imatinib', effect='resistance', disease_name='Melanoma', pmids=['24132921']
#
#
#
# --- Mismatch #4 (gemini-2.0-flash) ---
# ====================================================================================================
# ID: F4.2-000171-S1-P2
# Question: Which drugs target biomarkers of resistance to Dasatinib in Naevocarcinoma?
#
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# 📋 GOLD CYPHER (Expected Reference)
# ====================================================================================================
# ```cypher
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t1:Therapy)
# WHERE (
#   toLower(t1.name) = toLower('Dasatinib')
#   OR any(s IN coalesce(t1.synonyms, []) WHERE toLower(s) = toLower('Dasatinib'))
#   OR toLower(t1.name) CONTAINS toLower('Dasatinib')
# )
#   AND toLower(rel.effect) = 'resistance'
#   AND (
#     toLower(rel.disease_name) CONTAINS 'melanoma'
#   )
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(g:Gene)
# WITH CASE WHEN b:Gene THEN b.symbol ELSE g.symbol END AS gene_symbol
# WHERE gene_symbol IS NOT NULL
# MATCH (t2:Therapy)-[r:TARGETS]->(tg:Gene)
# WHERE (
#   toLower(tg.symbol) = toLower(gene_symbol)
#   OR any(s IN coalesce(tg.synonyms, []) WHERE toLower(s) = toLower(gene_symbol))
# )
#   AND toLower(t2.name) <> toLower('Dasatinib')
# RETURN
#   gene_symbol,
#   t2.name AS therapy_name,
#   r.moa AS targets_moa,
#   coalesce(r.ref_sources, []) AS ref_sources,
#   coalesce(r.ref_ids, []) AS ref_ids,
#   coalesce(r.ref_urls, []) AS ref_urls
# LIMIT 100
#
# ```
#
# 📊 GOLD RESULTS: 35 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] gene_symbol='BRAF', therapy_name='Agerafenib', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['Other', 'Other'], ref_ids=['http://ignyta.com/wp-content/uploads/2015/11/ENA-2015-poster-RXDX-105.pdf', 'http://ignyta.com/wp-content/uploads/2015/11/RXDX-105-ENA-Clinical-Poster.pdf'], ref_urls=['http://ignyta.com/wp-content/uploads/2015/11/ENA-2015-poster-RXDX-105.pdf', 'http://ignyta.com/wp-content/uploads/2015/11/RXDX-105-ENA-Clinical-Poster.pdf']
#   [  2] gene_symbol='BRAF', therapy_name='BRAF Inhibitor', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['DOI', 'PubMed'], ref_ids=['10.1158/1538-7445.AM2012-3790', '23617957'], ref_urls=['http://cancerres.aacrjournals.org/content/72/8_Supplement/3790', 'http://europepmc.org/abstract/MED/23617957']
#   [  3] gene_symbol='BRAF', therapy_name='Belvarafenib', targets_moa='RAF serine/threonine protein kinase inhibitor', ref_sources=['Other', 'Other'], ref_ids=['https://ascopubs.org/doi/abs/10.1200/JCO.2016.34.15_suppl.2570', 'https://ascopubs.org/doi/abs/10.1200/JCO.2019.37.15_suppl.3000'], ref_urls=['https://ascopubs.org/doi/abs/10.1200/JCO.2016.34.15_suppl.2570', 'https://ascopubs.org/doi/abs/10.1200/JCO.2019.37.15_suppl.3000']
#   [  4] gene_symbol='BRAF', therapy_name='Dabrafenib', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['DailyMed'], ref_ids=['setid=803beaaa-33f9-48cc-9a95-c2e887e095b4#nlm34090-1'], ref_urls=['http://dailymed.nlm.nih.gov/dailymed/lookup.cfm?setid=803beaaa-33f9-48cc-9a95-c2e887e095b4#nlm34090-1']
#   [  5] gene_symbol='BRAF', therapy_name='Encorafenib', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['DOI', 'PubMed'], ref_ids=['10.1158/1538-7445.AM2012-3790', '23617957'], ref_urls=['http://cancerres.aacrjournals.org/content/72/8_Supplement/3790', 'http://europepmc.org/abstract/MED/23617957']
#   [  6] gene_symbol='BRAF', therapy_name='Pan-RAF Inhibitor LY3009120', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['PubMed'], ref_ids=['25965804'], ref_urls=['http://europepmc.org/abstract/MED/25965804']
#   [  7] gene_symbol='BRAF', therapy_name='Regorafenib', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['Expert', 'FDA'], ref_ids=['REGORAFENIB', 'label/2012/203085lbl.pdf'], ref_urls=['http://chembl.blogspot.co.uk/search?q=REGORAFENIB', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2012/203085lbl.pdf']
#   [  8] gene_symbol='BRAF', therapy_name='Regorafenib Anhydrous', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['Expert', 'FDA'], ref_ids=['REGORAFENIB', 'label/2012/203085lbl.pdf'], ref_urls=['http://chembl.blogspot.co.uk/search?q=REGORAFENIB', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2012/203085lbl.pdf']
#   [  9] gene_symbol='BRAF', therapy_name='Sorafenib', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['FDA'], ref_ids=['label/2011/021923s012lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2011/021923s012lbl.pdf']
#   [ 10] gene_symbol='BRAF', therapy_name='Sorafenib Tosylate', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['FDA'], ref_ids=['label/2011/021923s012lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2011/021923s012lbl.pdf']
#   [ 11] gene_symbol='BRAF', therapy_name='TRK Inhibitor', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['Expert', 'FDA'], ref_ids=['REGORAFENIB', 'label/2012/203085lbl.pdf'], ref_urls=['http://chembl.blogspot.co.uk/search?q=REGORAFENIB', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2012/203085lbl.pdf']
#   [ 12] gene_symbol='BRAF', therapy_name='Tovorafenib', targets_moa='RAF serine/threonine protein kinase inhibitor', ref_sources=['Other', 'Other', 'PubMed'], ref_ids=['http://www.cancer.gov/publications/dictionaries/cancer-drug?cdrid=710688', 'http://www.sunesis.com/products-in-development/product/MLN2480.php', '5653214'], ref_urls=['http://europepmc.org/abstract/MED/5653214', 'http://www.cancer.gov/publications/dictionaries/cancer-drug?cdrid=710688', 'http://www.sunesis.com/products-in-development/product/MLN2480.php']
#   [ 13] gene_symbol='BRAF', therapy_name='Vemurafenib', targets_moa='Serine/threonine-protein kinase B-raf inhibitor', ref_sources=['FDA'], ref_ids=['label/2011/202429s000lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2011/202429s000lbl.pdf']
#   [ 14] gene_symbol='KIT', therapy_name='Amuvatinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['Other', 'PubMed', 'PubMed'], ref_ids=['http://www.google.com/patents/US20080226747', '24326130', '25110867'], ref_urls=['http://europepmc.org/abstract/MED/24326130', 'http://europepmc.org/abstract/MED/25110867', 'http://www.google.com/patents/US20080226747']
#   [ 15] gene_symbol='KIT', therapy_name='Avapritinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2020/212608s000lbl.pdf'], ref_urls=['https://www.accessdata.fda.gov/drugsatfda_docs/label/2020/212608s000lbl.pdf']
#   [ 16] gene_symbol='KIT', therapy_name='C-Met Inhibitor', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['http://www.exelixis.com/pipeline/xl880', '19808973'], ref_urls=['http://europepmc.org/abstract/MED/19808973', 'http://www.exelixis.com/pipeline/xl880']
#   [ 17] gene_symbol='KIT', therapy_name='Cediranib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['PubMed'], ref_ids=['15899831'], ref_urls=['http://europepmc.org/abstract/MED/15899831']
#   [ 18] gene_symbol='KIT', therapy_name='Dovitinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['PubMed'], ref_ids=['15897558'], ref_urls=['http://europepmc.org/abstract/MED/15897558']
#   [ 19] gene_symbol='KIT', therapy_name='Foretinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['http://www.exelixis.com/pipeline/xl880', '19808973'], ref_urls=['http://europepmc.org/abstract/MED/19808973', 'http://www.exelixis.com/pipeline/xl880']
#   [ 20] gene_symbol='KIT', therapy_name='Imatinib', targets_moa='Stem cell growth factor receptor inhibitor', ref_sources=['DailyMed', 'FDA', 'Wikipedia'], ref_ids=['setid=211ef2da-2868-4a77-8055-1cb2cd78e24b#section-13', 'label/2008/021588s024lbl.pdf', 'Bcr-Abl_tyrosine-kinase_inhibitor'], ref_urls=['http://dailymed.nlm.nih.gov/dailymed/lookup.cfm?setid=211ef2da-2868-4a77-8055-1cb2cd78e24b#section-13', 'http://en.wikipedia.org/wiki/Bcr-Abl_tyrosine-kinase_inhibitor', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2008/021588s024lbl.pdf']
#   ... (15 more rows)
#
# ====================================================================================================
# 🔧 GENERATED CYPHER (Model Output)
# ====================================================================================================
# ```cypher
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t:Therapy)
# WHERE (
#   toLower(t.name) = toLower('dasatinib')
#   OR any(s IN coalesce(t.synonyms, []) WHERE toLower(s) = toLower('dasatinib'))
#   OR toLower(t.name) CONTAINS toLower('dasatinib')
# )
# AND toLower(rel.effect) = 'resistance'
# AND toLower(rel.disease_name) CONTAINS toLower('naevocarcinoma')
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(g:Gene)
# WITH b, rel, t, g,
#   CASE
#     WHEN b:Gene THEN b.symbol
#     ELSE g.symbol
#   END AS gene_symbol
# MATCH (t2:Therapy)-[:TARGETS]->(g2:Gene)
# WHERE g2.symbol = gene_symbol
# RETURN
#   CASE WHEN b:Variant THEN coalesce(b.name, b.hgvs_p) END AS variant_name,
#   gene_symbol,
#   t2.name AS therapy_name,
#   rel.effect AS effect,
#   rel.disease_name AS disease_name,
#   coalesce(rel.pmids, []) AS pmids
# LIMIT 100
# ```
#
# 📊 GENERATED RESULTS: 0 row(s)
# ----------------------------------------------------------------------------------------------------
#   (no results)
#
#
#
# --- Mismatch #5 (gemini-2.0-flash) ---
# ====================================================================================================
# ID: F4.2-000042-P3
# Question: Find therapies that target resistance genes for Gemcitabine in Pancreatic Adenocarcinoma.
#
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# 📋 GOLD CYPHER (Expected Reference)
# ====================================================================================================
# ```cypher
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t1:Therapy)
# WHERE (
#   toLower(t1.name) = toLower('Gemcitabine')
#   OR any(s IN coalesce(t1.synonyms, []) WHERE toLower(s) = toLower('Gemcitabine'))
#   OR toLower(t1.name) CONTAINS toLower('Gemcitabine')
# )
#   AND toLower(rel.effect) = 'resistance'
#   AND (
#     toLower(rel.disease_name) CONTAINS 'pancreatic' AND
#     toLower(rel.disease_name) CONTAINS 'adenocarcinoma'
#   )
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(g:Gene)
# WITH CASE WHEN b:Gene THEN b.symbol ELSE g.symbol END AS gene_symbol
# WHERE gene_symbol IS NOT NULL
# MATCH (t2:Therapy)-[r:TARGETS]->(tg:Gene)
# WHERE (
#   toLower(tg.symbol) = toLower(gene_symbol)
#   OR any(s IN coalesce(tg.synonyms, []) WHERE toLower(s) = toLower(gene_symbol))
# )
#   AND toLower(t2.name) <> toLower('Gemcitabine')
# RETURN
#   gene_symbol,
#   t2.name AS therapy_name,
#   r.moa AS targets_moa,
#   coalesce(r.ref_sources, []) AS ref_sources,
#   coalesce(r.ref_ids, []) AS ref_ids,
#   coalesce(r.ref_urls, []) AS ref_urls
# LIMIT 100
#
# ```
#
# 📊 GOLD RESULTS: 3 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] gene_symbol='KRAS', therapy_name='Adagrasib', targets_moa='GTPase KRas inhibitor', ref_sources=['PubMed'], ref_ids=['31658955'], ref_urls=['https://pubmed.ncbi.nlm.nih.gov/31658955/']
#   [  2] gene_symbol='KRAS', therapy_name='Salirasib', targets_moa='RAS inhibitor', ref_sources=['PubMed'], ref_ids=['22547163'], ref_urls=['https://pubmed.ncbi.nlm.nih.gov/22547163/']
#   [  3] gene_symbol='KRAS', therapy_name='Sotorasib', targets_moa='GTPase KRas inhibitor', ref_sources=['PubMed', 'PubMed', 'PubMed', 'PubMed'], ref_ids=['31189530', '31666701', '31820981', '32568546'], ref_urls=['http://europepmc.org/abstract/MED/31189530', 'http://europepmc.org/abstract/MED/31666701', 'http://europepmc.org/abstract/MED/31820981', 'http://europepmc.org/abstract/MED/32568546']
#
# ====================================================================================================
# 🔧 GENERATED CYPHER (Model Output)
# ====================================================================================================
# ```cypher
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t:Therapy)
# WHERE (
#     toLower(t.name) = toLower('Gemcitabine')
#     OR any(s IN coalesce(t.synonyms, []) WHERE toLower(s) = toLower('Gemcitabine'))
#     OR toLower(t.name) CONTAINS toLower('Gemcitabine')
#   )
#   AND toLower(rel.effect) = toLower('resistance')
#   AND toLower(rel.disease_name) CONTAINS toLower('pancreatic')
#   AND toLower(rel.disease_name) CONTAINS toLower('adenocarcinoma')
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(g:Gene)
# RETURN
#   CASE WHEN b:Variant THEN coalesce(b.name, b.hgvs_p) END AS variant_name,
#   CASE WHEN b:Gene THEN b.symbol ELSE g.symbol END AS gene_symbol,
#   t.name AS therapy_name,
#   rel.effect AS effect,
#   rel.disease_name AS disease_name,
#   coalesce(rel.pmids, []) AS pmids
# LIMIT 100
# ```
#
# 📊 GENERATED RESULTS: 2 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] variant_name='KRAS G12/G13', gene_symbol='KRAS', therapy_name='Gemcitabine', effect='resistance', disease_name='Pancreatic Adenocarcinoma', pmids=['24915778']
#   [  2] variant_name='RB1 Overexpression', gene_symbol='RB1', therapy_name='Gemcitabine', effect='resistance', disease_name='Pancreatic Adenocarcinoma', pmids=['11792751']
#
#
#
# --- Mismatch #6 (gemini-2.0-flash) ---
# ====================================================================================================
# ID: F4.1-000047-P1
# Question: What drugs targeting ALK have biomarker evidence in Diffuse Large B-cell Lymphoma?
#
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# 📋 GOLD CYPHER (Expected Reference)
# ====================================================================================================
# ```cypher
# MATCH (t:Therapy)-[:TARGETS]->(g:Gene)
# WHERE toLower(g.symbol) = toLower('ALK')
#    OR any(s IN coalesce(g.synonyms, []) WHERE toLower(s) = toLower('ALK'))
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t)
# WHERE (
#     toLower(rel.disease_name) CONTAINS 'diffuse' AND
#     toLower(rel.disease_name) CONTAINS 'large' AND
#     toLower(rel.disease_name) CONTAINS 'b-cell' AND
#     toLower(rel.disease_name) CONTAINS 'lymphoma'
#   )
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(bg:Gene)
# RETURN
#   CASE WHEN b:Variant THEN b.name ELSE NULL END AS variant_name,
#   CASE WHEN b:Gene THEN b.symbol ELSE bg.symbol END AS gene_symbol,
#   t.name AS therapy_name,
#   rel.effect AS effect,
#   rel.disease_name AS disease_name,
#   coalesce(rel.pmids, []) AS pmids
# LIMIT 100
#
# ```
#
# 📊 GOLD RESULTS: 1 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] variant_name='CLTC CLTC::ALK Fusion', gene_symbol='CLTC', therapy_name='Crizotinib', effect='sensitivity', disease_name='Diffuse Large B-cell Lymphoma', pmids=['26221234']
#
# ====================================================================================================
# 🔧 GENERATED CYPHER (Model Output)
# ====================================================================================================
# ```cypher
# MATCH (t:Therapy)-[:TARGETS]->(g:Gene)
# WHERE toLower(g.symbol) = toLower('ALK')
#    OR any(s IN coalesce(g.synonyms, []) WHERE toLower(s) = toLower('ALK'))
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t)
# WHERE toLower(rel.disease_name) CONTAINS toLower('diffuse')
#   AND toLower(rel.disease_name) CONTAINS toLower('large')
#   AND toLower(rel.disease_name) CONTAINS toLower('b-cell')
#   AND toLower(rel.disease_name) CONTAINS toLower('lymphoma')
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(gene:Gene)
# RETURN
#   CASE WHEN b:Gene THEN b.symbol ELSE gene.symbol END AS gene_symbol,
#   t.name AS therapy_name,
#   rel.effect AS effect,
#   rel.disease_name AS disease_name,
#   coalesce(rel.pmids, []) AS pmids
# LIMIT 100
# ```
#
# 📊 GENERATED RESULTS: 1 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] gene_symbol='CLTC', therapy_name='Crizotinib', effect='sensitivity', disease_name='Diffuse Large B-cell Lymphoma', pmids=['26221234']
#
#
#
# --- Mismatch #7 (gemini-2.0-flash) ---
# ====================================================================================================
# ID: F4.1-000072-S1-P3
# Question: Show treatments hitting ALK that have biomarker evidence in Stromal Tumour Of Gastrointestinal Tract.
#
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# 📋 GOLD CYPHER (Expected Reference)
# ====================================================================================================
# ```cypher
# MATCH (t:Therapy)-[:TARGETS]->(g:Gene)
# WHERE toLower(g.symbol) = toLower('ALK')
#    OR any(s IN coalesce(g.synonyms, []) WHERE toLower(s) = toLower('ALK'))
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t)
# WHERE (
#     toLower(rel.disease_name) CONTAINS 'gastrointestinal' AND
#     toLower(rel.disease_name) CONTAINS 'stromal' AND
#     toLower(rel.disease_name) CONTAINS 'tumor'
#   )
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(bg:Gene)
# RETURN
#   CASE WHEN b:Variant THEN b.name ELSE NULL END AS variant_name,
#   CASE WHEN b:Gene THEN b.symbol ELSE bg.symbol END AS gene_symbol,
#   t.name AS therapy_name,
#   rel.effect AS effect,
#   rel.disease_name AS disease_name,
#   coalesce(rel.pmids, []) AS pmids
# LIMIT 100
#
# ```
#
# 📊 GOLD RESULTS: 1 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] variant_name='ETV6 ETV6::NTRK3 Fusion', gene_symbol='ETV6', therapy_name='Entrectinib', effect='sensitivity', disease_name='Gastrointestinal Stromal Tumor', pmids=['40900786']
#
# ====================================================================================================
# 🔧 GENERATED CYPHER (Model Output)
# ====================================================================================================
# ```cypher
# MATCH (t:Therapy)-[:TARGETS]->(g:Gene)
# WHERE toLower(g.symbol) = toLower('ALK')
#    OR any(s IN coalesce(g.synonyms, []) WHERE toLower(s) = toLower('ALK'))
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t)
# WHERE toLower(rel.disease_name) CONTAINS toLower('stromal')
#   AND toLower(rel.disease_name) CONTAINS toLower('tumour')
#   AND toLower(rel.disease_name) CONTAINS toLower('gastrointestinal')
#   AND toLower(rel.disease_name) CONTAINS toLower('tract')
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(gene:Gene)
# RETURN
#   CASE WHEN b:Gene THEN b.symbol ELSE gene.symbol END AS gene_symbol,
#   t.name AS therapy_name,
#   rel.effect AS effect,
#   rel.disease_name AS disease_name,
#   coalesce(rel.pmids, []) AS pmids
# LIMIT 100
# ```
#
# 📊 GENERATED RESULTS: 0 row(s)
# ----------------------------------------------------------------------------------------------------
#   (no results)
#
#
#
# --- Mismatch #8 (gemini-2.0-flash) ---
# ====================================================================================================
# ID: F4.1-000096
# Question: Which therapies target ALK and also have biomarker evidence in Glioblastoma?
#
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# 📋 GOLD CYPHER (Expected Reference)
# ====================================================================================================
# ```cypher
# MATCH (t:Therapy)-[:TARGETS]->(g:Gene)
# WHERE toLower(g.symbol) = toLower('ALK')
#    OR any(s IN coalesce(g.synonyms, []) WHERE toLower(s) = toLower('ALK'))
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t)
# WHERE (
#     toLower(rel.disease_name) CONTAINS 'glioblastoma'
#   )
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(bg:Gene)
# RETURN
#   CASE WHEN b:Variant THEN b.name ELSE NULL END AS variant_name,
#   CASE WHEN b:Gene THEN b.symbol ELSE bg.symbol END AS gene_symbol,
#   t.name AS therapy_name,
#   rel.effect AS effect,
#   rel.disease_name AS disease_name,
#   coalesce(rel.pmids, []) AS pmids
# LIMIT 100
#
# ```
#
# 📊 GOLD RESULTS: 5 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] variant_name='ALK Expression', gene_symbol='ALK', therapy_name='Crizotinib', effect='sensitivity', disease_name='Glioblastoma', pmids=['26498130']
#   [  2] variant_name='MET Amplification', gene_symbol='MET', therapy_name='Crizotinib', effect='sensitivity', disease_name='Glioblastoma', pmids=['22162573']
#   [  3] variant_name='BCR BCR::NTRK2 Fusion', gene_symbol='BCR', therapy_name='Entrectinib', effect='sensitivity', disease_name='Brain Glioblastoma Multiforme', pmids=['35673607']
#   [  4] variant_name='ETV6 ETV6::NTRK3 Fusion', gene_symbol='ETV6', therapy_name='Entrectinib', effect='sensitivity', disease_name='Glioblastoma', pmids=['35395680']
#   [  5] variant_name='GOPC GOPC::ROS1 e7::e35', gene_symbol='GOPC', therapy_name='Lorlatinib', effect='sensitivity', disease_name='Glioblastoma', pmids=['30171048']
#
# ====================================================================================================
# 🔧 GENERATED CYPHER (Model Output)
# ====================================================================================================
# ```cypher
# MATCH (t:Therapy)-[r:TARGETS]->(g:Gene)
# WHERE toLower(g.symbol) = toLower('ALK')
#    OR any(s IN coalesce(g.synonyms, []) WHERE toLower(s) = toLower('ALK'))
# OPTIONAL MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t)
# WHERE toLower(rel.disease_name) CONTAINS toLower('glioblastoma')
# OPTIONAL MATCH (b)-[:VARIANT_OF]->(gene:Gene)
# RETURN
#     CASE WHEN b IS NOT NULL AND b:Variant THEN coalesce(b.name, b.hgvs_p) ELSE NULL END AS variant_name,
#     g.symbol AS gene_symbol,
#     t.name AS therapy_name,
#     CASE WHEN rel IS NOT NULL THEN rel.effect ELSE NULL END AS effect,
#     CASE WHEN rel IS NOT NULL THEN rel.disease_name ELSE NULL END AS disease_name,
#     r.moa AS targets_moa,
#     coalesce(r.ref_sources, []) AS ref_sources,
#     coalesce(r.ref_ids, []) AS ref_ids,
#     coalesce(r.ref_urls, []) AS ref_urls,
#     coalesce(rel.pmids, []) AS pmids
# LIMIT 100
# ```
#
# 📊 GENERATED RESULTS: 10 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] variant_name=None, gene_symbol='ALK', therapy_name='ALK Inhibitor ASP3026', effect=None, disease_name=None, targets_moa='ALK tyrosine kinase receptor inhibitor', ref_sources=['PubMed'], ref_ids=['24419060'], ref_urls=['http://europepmc.org/abstract/MED/24419060'], pmids=[]
#   [  2] variant_name=None, gene_symbol='ALK', therapy_name='Alectinib', effect=None, disease_name=None, targets_moa='ALK tyrosine kinase receptor inhibitor | EML4-ALK', ref_sources=['FDA', 'FDA'], ref_ids=['label/2015/208434s000lbl.pdf', 'nda/2015/208434Orig1s000ClinPharmR.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2015/208434s000lbl.pdf', 'https://www.accessdata.fda.gov/drugsatfda_docs/nda/2015/208434Orig1s000ClinPharmR.pdf'], pmids=[]
#   [  3] variant_name=None, gene_symbol='ALK', therapy_name='Brigatinib', effect=None, disease_name=None, targets_moa='ALK tyrosine kinase receptor inhibitor', ref_sources=['Other', 'Other', 'PubMed'], ref_ids=['http://www.ariad.com/AP26113', 'http://www.ariad.com/pdf/Rivera_2012_AACR_POSTER_AP26113_noQRcode.pdf', '25888090'], ref_urls=['http://europepmc.org/abstract/MED/25888090', 'http://www.ariad.com/AP26113', 'http://www.ariad.com/pdf/Rivera_2012_AACR_POSTER_AP26113_noQRcode.pdf'], pmids=[]
#   [  4] variant_name=None, gene_symbol='ALK', therapy_name='Ceritinib', effect=None, disease_name=None, targets_moa='ALK tyrosine kinase receptor inhibitor | EML4-ALK | NPM/ALK (Nucleophosmin/ALK tyrosine kinase receptor)', ref_sources=['FDA', 'FDA'], ref_ids=['label/2014/205755s000lbl.pdf', 'label/2017/205755s009lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2014/205755s000lbl.pdf', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2017/205755s009lbl.pdf'], pmids=[]
#   [  5] variant_name='ALK Expression', gene_symbol='ALK', therapy_name='Crizotinib', effect='sensitivity', disease_name='Glioblastoma', targets_moa='ALK tyrosine kinase receptor inhibitor | EML4-ALK | NPM/ALK (Nucleophosmin/ALK tyrosine kinase receptor)', ref_sources=['FDA', 'FDA'], ref_ids=['label/2012/202570s003lbl.pdf', 'label/2017/202570s021lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2012/202570s003lbl.pdf', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2017/202570s021lbl.pdf'], pmids=['26498130']
#   [  6] variant_name='MET Amplification', gene_symbol='ALK', therapy_name='Crizotinib', effect='sensitivity', disease_name='Glioblastoma', targets_moa='ALK tyrosine kinase receptor inhibitor | EML4-ALK | NPM/ALK (Nucleophosmin/ALK tyrosine kinase receptor)', ref_sources=['FDA', 'FDA'], ref_ids=['label/2012/202570s003lbl.pdf', 'label/2017/202570s021lbl.pdf'], ref_urls=['http://www.accessdata.fda.gov/drugsatfda_docs/label/2012/202570s003lbl.pdf', 'https://www.accessdata.fda.gov/drugsatfda_docs/label/2017/202570s021lbl.pdf'], pmids=['22162573']
#   [  7] variant_name=None, gene_symbol='ALK', therapy_name='Ensartinib', effect=None, disease_name=None, targets_moa='ALK tyrosine kinase receptor inhibitor', ref_sources=['Other', 'PubMed'], ref_ids=['http://www.xcovery.com/our-science/alk-inhibitor/', '25322323'], ref_urls=['http://europepmc.org/abstract/MED/25322323', 'http://www.xcovery.com/our-science/alk-inhibitor/'], pmids=[]
#   [  8] variant_name='BCR BCR::NTRK2 Fusion', gene_symbol='ALK', therapy_name='Entrectinib', effect='sensitivity', disease_name='Brain Glioblastoma Multiforme', targets_moa='ALK tyrosine kinase receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2019/212725s000lbl.pdf'], ref_urls=['https://www.accessdata.fda.gov/drugsatfda_docs/label/2019/212725s000lbl.pdf'], pmids=['35673607']
#   [  9] variant_name='ETV6 ETV6::NTRK3 Fusion', gene_symbol='ALK', therapy_name='Entrectinib', effect='sensitivity', disease_name='Glioblastoma', targets_moa='ALK tyrosine kinase receptor inhibitor', ref_sources=['FDA'], ref_ids=['label/2019/212725s000lbl.pdf'], ref_urls=['https://www.accessdata.fda.gov/drugsatfda_docs/label/2019/212725s000lbl.pdf'], pmids=['35395680']
#   [ 10] variant_name='GOPC GOPC::ROS1 e7::e35', gene_symbol='ALK', therapy_name='Lorlatinib', effect='sensitivity', disease_name='Glioblastoma', targets_moa='ALK tyrosine kinase receptor inhibitor | EML4-ALK  inhibitor', ref_sources=['FDA'], ref_ids=['label/2018/210868s000lbl.pdf'], ref_urls=['https://www.accessdata.fda.gov/drugsatfda_docs/label/2018/210868s000lbl.pdf'], pmids=['30171048']
#
#
#
# --- Mismatch #9 (gemini-2.0-flash) ---
# ====================================================================================================
# ID: F2.2-000185-S1
# Question: How does the variant RPS6 PHOSPHORYLATION affect response to Everolimus in Adenocarcinoma Of Stomach?
#
# ----------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# 📋 GOLD CYPHER (Expected Reference)
# ====================================================================================================
# ```cypher
# MATCH (v:Variant {name: 'RPS6 PHOSPHORYLATION'})-[:VARIANT_OF]->(g:Gene)
# MATCH (v)-[rel:AFFECTS_RESPONSE_TO]->(t:Therapy)
# WHERE (
#   toLower(t.name) = toLower('Everolimus')
#   OR any(s IN coalesce(t.synonyms, []) WHERE toLower(s) = toLower('Everolimus'))
#   OR toLower(t.name) CONTAINS toLower('Everolimus')
# )
# AND (
#     toLower(rel.disease_name) CONTAINS 'gastric' AND
#     toLower(rel.disease_name) CONTAINS 'adenocarcinoma'
#   )
# RETURN
#   v.name AS variant_name,
#   g.symbol AS gene_symbol,
#   t.name AS therapy_name,
#   rel.effect AS effect,
#   rel.disease_name AS disease_name,
#   coalesce(rel.pmids, []) AS pmids
# LIMIT 100
#
# ```
#
# 📊 GOLD RESULTS: 1 row(s)
# ----------------------------------------------------------------------------------------------------
#   [  1] variant_name='RPS6 PHOSPHORYLATION', gene_symbol='RPS6', therapy_name='Everolimus', effect='sensitivity', disease_name='Gastric Adenocarcinoma', pmids=['22343617']
#
# ====================================================================================================
# 🔧 GENERATED CYPHER (Model Output)
# ====================================================================================================
# ```cypher
# MATCH (b:Biomarker)-[rel:AFFECTS_RESPONSE_TO]->(t:Therapy)
# WHERE (
#     toLower(t.name) = toLower('Everolimus')
#     OR any(s IN coalesce(t.synonyms, [])
#            WHERE toLower(s) = toLower('Everolimus'))
#     OR toLower(t.name) CONTAINS toLower('Everolimus')
# )
# WITH b, rel, t
# WHERE b:Variant AND toLower(b.name) CONTAINS toLower('RPS6 PHOSPHORYLATION')
# MATCH (b)-[:VARIANT_OF]->(g:Gene)
# WHERE toLower(rel.disease_name) CONTAINS toLower('adenocarcinoma')
#   AND toLower(rel.disease_name) CONTAINS toLower('of')
#   AND toLower(rel.disease_name) CONTAINS toLower('stomach')
# RETURN
#   b.name AS variant_name,
#   g.symbol AS gene_symbol,
#   t.name AS therapy_name,
#   rel.effect AS effect,
#   rel.disease_name AS disease_name,
#   coalesce(rel.pmids, []) AS pmids
# LIMIT 100
# ```
#
# 📊 GENERATED RESULTS: 0 row(s)
# ----------------------------------------------------------------------------------------------------
#   (no results)

# %%
# Save Final Results Summary

from datetime import datetime

results_summary = {
    "timestamp": datetime.now().isoformat(),
    "test_set_size": len(test_records),
    "models": {},
}

# Add all evaluated models
for model_id, metrics in all_metrics.items():
    results_summary["models"][model_id] = {
        "metrics": metrics,
        "result_count": len(all_results.get(model_id, [])),
    }

results_file = EVAL_DIR / "evaluation_results.json"
with results_file.open("w", encoding="utf-8") as f:
    json.dump(results_summary, f, indent=2, ensure_ascii=False)

print(f"\nFinal results summary saved to: {results_file}")
print("\nEvaluation complete!")
# Out:
# Final results summary saved to: C:\Users\ishui\Desktop\OncoGraph\OncoGraph Agent\finetuning\evaluation\results\evaluation_results.json
#
# Evaluation complete!

# %%
# Interactive Inspection Tool


def inspect_by_id(record_id: str, model_id: str | None = None):
    """Inspect a specific record by ID across all evaluated models.

    Args:
        record_id: The record ID to search for.
        model_id: Optional model ID to search in. If None, searches all models.
    """
    if model_id:
        # Search in specific model
        if model_id in all_results:
            for record in all_results[model_id]:
                if record.get("id") == record_id:
                    print(f"\nFound in {model_id}:")
                    inspect_record(record, max_rows_display=50)
                    return
            print(f"Record with ID '{record_id}' not found in {model_id}.")
        else:
            print(f"Model '{model_id}' not found. Available models: {list(all_results.keys())}")
    else:
        # Search across all models
        found = False
        for mid, results in all_results.items():
            for record in results:
                if record.get("id") == record_id:
                    print(f"\nFound in {mid}:")
                    inspect_record(record, max_rows_display=50)
                    found = True
                    break
            if found:
                break
        if not found:
            print(f"Record with ID '{record_id}' not found in any model.")


print("\nUse inspect_by_id('RECORD_ID') to inspect a specific record in detail.")
print("Use inspect_by_id('RECORD_ID', 'model_id') to search in a specific model.")
print("Example: inspect_by_id('F5.2-000167-S1-P2')")
print("Example: inspect_by_id('F5.2-000167-S1-P2', 'gemini-2.0-flash')")
# Out:
# Use inspect_by_id('RECORD_ID') to inspect a specific record in detail.
# Use inspect_by_id('RECORD_ID', 'model_id') to search in a specific model.
# Example: inspect_by_id('F5.2-000167-S1-P2')
# Example: inspect_by_id('F5.2-000167-S1-P2', 'gemini-2.0-flash')
